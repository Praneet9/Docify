# %% [markdown]
# # Contour Detection on Driving Licence

# %%
import cv2
import matplotlib.pyplot as plt
from matplotlib import path
import statistics as st

# %matplotlib inline

# PATH="C:\\Users\\Dell inspiron\\Desktop\\CurrentWorkingDirectory\\OCR\\test_data"

# os.chdir(PATH);
Image=cv2.imread('license2.jpg');
I=Image.copy();
img = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(img,(11,11),0)
th = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
# plt.imshow(th, cmap=plt.cm.gray)
# plt.show();
img=cv2.bitwise_not(th, th)
# plt.imshow(img, cmap=plt.cm.gray)
# plt.show();

"""G_Image = cv2.cvtColor(Image,cv2.COLOR_BGR2GRAY)
I=Image.copy();
i=Image.copy(); 
p=PreprocessingEngine(Image)
img=p.getGrayImage();
img=p.reduceNoise();
img=p.eliminateBackground();
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
#Otsu Thresholding
blur = cv2.GaussianBlur(G_Image,(1,1),0)
ret,th = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
"""
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_TC89_KCOS )
#img = cv2.drawContours(Image, contours, -1, (0,255,0), 3)
count=0
a=list();
areas=list();
width=list();
height=list();
for contour in contours:
        [x,y,w,h]=cv2.boundingRect(contour)
        width.append(w)
        height.append(h)
        areas.append(cv2.contourArea(contour))

median=st.median(areas)
width=st.median(width);
height=st.median(height)


        
for contour in contours:
        # get rectangle bounding contour
        [x, y, w, h] = cv2.boundingRect(contour)
        if h*w*10>median and h in range(15, 90) and w in range(4,85):
                count+=1
                a.append(contour);
                if w>width:
                        cv2.rectangle(I, (x, y), (x + int(width), y + h), (255, 10, 0), 0)
                        w=int(w-width);
                        x=int(x+width);
                        cv2.rectangle(I, (x,y), (x+w, y+h), (255, 10, 0),0)
                else:
                        cv2.rectangle(I, (x, y), (x + w, y + h), (255, 10, 0), 0)
                        

extracted_image=list();
for contour in a:
        [x, y, w, h] = cv2.boundingRect(contour)
        new_image=img[y:y+h, x:x+w]
        extracted_image.append(new_image)
        
# for img in extracted_image:
#     cv2.imshow('img', img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
        
# cv2.imshow('Image', I)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
cv2.imwrite('license_con.jpg', I)
# Out:
# True

# %% [markdown]
# # For PAN Card

# %%
import cv2
import matplotlib.pyplot as plt
from matplotlib import path
import statistics as st

# %matplotlib inline

# PATH="C:\\Users\\Dell inspiron\\Desktop\\CurrentWorkingDirectory\\OCR\\test_data"

# os.chdir(PATH);
Image=cv2.imread('pancard.jpg');
Image = cv2.resize(Image, (1678, 1084))
I=Image.copy();
img = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(img,(11,11),0)
th = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
# plt.imshow(th, cmap=plt.cm.gray)
# plt.show();
img=cv2.bitwise_not(th, th)
# plt.imshow(img, cmap=plt.cm.gray)
# plt.show();

"""G_Image = cv2.cvtColor(Image,cv2.COLOR_BGR2GRAY)
I=Image.copy();
i=Image.copy(); 
p=PreprocessingEngine(Image)
img=p.getGrayImage();
img=p.reduceNoise();
img=p.eliminateBackground();
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
#Otsu Thresholding
blur = cv2.GaussianBlur(G_Image,(1,1),0)
ret,th = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
"""
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_TC89_KCOS )
#img = cv2.drawContours(Image, contours, -1, (0,255,0), 3)
count=0
a=list();
areas=list();
width=list();
height=list();
for contour in contours:
        [x,y,w,h]=cv2.boundingRect(contour)
        width.append(w)
        height.append(h)
        areas.append(cv2.contourArea(contour))

median=st.median(areas)
width=st.median(width);
height=st.median(height)


        
for contour in contours:
        # get rectangle bounding contour
        [x, y, w, h] = cv2.boundingRect(contour)
        if h*w*10>median and h in range(15, 90) and w in range(4,85):
                count+=1
                a.append(contour);
                if w>width:
                        cv2.rectangle(I, (x, y), (x + int(width), y + h), (10, 255, 0), 2)
                        w=int(w-width);
                        x=int(x+width);
                        cv2.rectangle(I, (x,y), (x+w, y+h), (10, 255, 0), 2)
                else:
                        cv2.rectangle(I, (x, y), (x + w, y + h), (10, 255, 0), 2)
                        

extracted_image=list();
for contour in a:
        [x, y, w, h] = cv2.boundingRect(contour)
        new_image=img[y:y+h, x:x+w]
        extracted_image.append(new_image)
        
# for img in extracted_image:
#     cv2.imshow('img', img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
        
# cv2.imshow('Image', I)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
cv2.imwrite('pan_card_contours.jpg', I)
# Out:
# True

# %% [markdown]
# # Eroding to Remove connected components in PanCard

# %%
import cv2
import matplotlib.pyplot as plt
from matplotlib import path
import statistics as st
import numpy as np

# %matplotlib inline

# PATH="C:\\Users\\Dell inspiron\\Desktop\\CurrentWorkingDirectory\\OCR\\test_data"

# os.chdir(PATH);
Image=cv2.imread('pancard.jpg');
Image = cv2.resize(Image, (1678, 1084))
I=Image.copy();
img = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
img = cv2.erode(img, (5,5), iterations=1)
blur = cv2.GaussianBlur(img,(11,11),0)
th = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
# plt.show();
img=cv2.bitwise_not(th, th)
# plt.imshow(img, cmap=plt.cm.gray)
# plt.show();

"""G_Image = cv2.cvtColor(Image,cv2.COLOR_BGR2GRAY)
I=Image.copy();
i=Image.copy(); 
p=PreprocessingEngine(Image)
img=p.getGrayImage();
img=p.reduceNoise();
img=p.eliminateBackground();
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
#Otsu Thresholding
blur = cv2.GaussianBlur(G_Image,(1,1),0)
ret,th = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
"""
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_TC89_KCOS )
#img = cv2.drawContours(Image, contours, -1, (0,255,0), 3)
count=0
a=list();
areas=list();
width=list();
height=list();
for contour in contours:
        [x,y,w,h]=cv2.boundingRect(contour)
        width.append(w)
        height.append(h)
        areas.append(cv2.contourArea(contour))

median=st.median(areas)
width=st.median(width);
height=st.median(height)


        
for contour in contours:
        # get rectangle bounding contour
        [x, y, w, h] = cv2.boundingRect(contour)
        if h*w*10>median and h in range(15, 90) and w in range(4,85):
                count+=1
                a.append(contour);
                if w>width:
                        cv2.rectangle(I, (x, y), (x + int(width), y + h), (10, 255, 0), 2)
                        w=int(w-width);
                        x=int(x+width);
                        cv2.rectangle(I, (x,y), (x+w, y+h), (10, 255, 0), 2)
                else:
                        cv2.rectangle(I, (x, y), (x + w, y + h), (10, 255, 0), 2)
                        

extracted_image=list();
for contour in a:
        [x, y, w, h] = cv2.boundingRect(contour)
        new_image=img[y:y+h, x:x+w]
        extracted_image.append(new_image)
        
# for img in extracted_image:
#     cv2.imshow('img', img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
        
# cv2.imshow('Image', I)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
cv2.imwrite('pan_card_dcontours.jpg', I)
# Out:
# True

# %% [markdown]
# # Contour Detection on Driving Licence with Erosion to remove connected components

# %%
import cv2
import matplotlib.pyplot as plt
from matplotlib import path
import statistics as st
import numpy as np
# %matplotlib inline

# PATH="C:\\Users\\Dell inspiron\\Desktop\\CurrentWorkingDirectory\\OCR\\test_data"

# os.chdir(PATH);
Image=cv2.imread('license2.jpg');
I=Image.copy();
img = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
img = cv2.dilate(img, (7,7), iterations=1)
blur = cv2.GaussianBlur(img,(11,11),0)
th = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
# plt.imshow(th, cmap=plt.cm.gray)
# plt.show();
img=cv2.bitwise_not(th, th)
# plt.imshow(img, cmap=plt.cm.gray)
# plt.show();

"""G_Image = cv2.cvtColor(Image,cv2.COLOR_BGR2GRAY)
I=Image.copy();
i=Image.copy(); 
p=PreprocessingEngine(Image)
img=p.getGrayImage();
img=p.reduceNoise();
img=p.eliminateBackground();
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
#Otsu Thresholding
blur = cv2.GaussianBlur(G_Image,(1,1),0)
ret,th = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
"""
image, contours, hierarchy = cv2.findContours(img,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_TC89_KCOS )
#img = cv2.drawContours(Image, contours, -1, (0,255,0), 3)
count=0
a=list();
areas=list();
width=list();
height=list();
for contour in contours:
        [x,y,w,h]=cv2.boundingRect(contour)
        width.append(w)
        height.append(h)
        areas.append(cv2.contourArea(contour))

median=st.median(areas)
width=st.median(width);
height=st.median(height)


        
for contour in contours:
        # get rectangle bounding contour
        [x, y, w, h] = cv2.boundingRect(contour)
        if h*w*10>median and h in range(15, 90) and w in range(4,85):
                count+=1
                a.append(contour);
                if w>width:
                        cv2.rectangle(I, (x, y), (x + int(width), y + h), (255, 10, 0), 0)
                        w=int(w-width);
                        x=int(x+width);
                        cv2.rectangle(I, (x,y), (x+w, y+h), (255, 10, 0),0)
                else:
                        cv2.rectangle(I, (x, y), (x + w, y + h), (255, 10, 0), 0)
                        

extracted_image=list();
for contour in a:
        [x, y, w, h] = cv2.boundingRect(contour)
        new_image=img[y:y+h, x:x+w]
        extracted_image.append(new_image)
        
# for img in extracted_image:
#     cv2.imshow('img', img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
        
# cv2.imshow('Image', I)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
cv2.imwrite('license_econ.jpg', I)
# Out:
# True
